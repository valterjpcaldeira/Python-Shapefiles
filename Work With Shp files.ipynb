# %%
import shapefile
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sf = shapefile.Reader("shapefiles/concelhos")

# %%
sns.set(style='whitegrid', palette='pastel', color_codes=True)
sns.mpl.rc('figure', figsize=(10,6))

# %%
# %matplotlib inline

# %%
sf.records()[1]
# Out:
# Record #1: [182, 'PRT', 'Portugal', 1, 'Évora', 2, 'Alandroal', 'PT.EV.AL', 0, '0701', 'Concelho', 'Municipality', '', '']

# %%
def read_shapefile(sf):
    """
    Read a shapefile into a Pandas dataframe with a 'coords' 
    column holding the geometry information. This uses the pyshp
    package
    """
    fields = [x[0] for x in sf.fields][1:]
    records = sf.records()
    shps = [s.points for s in sf.shapes()]
    df = pd.DataFrame(columns=fields, data=records)
    df = df.assign(coords=shps)
    return df

# %%
df_geo = read_shapefile(sf)
df_geo.shape
# Out:
# (308, 15)

# %%
df_geo.head()
# Out:
#    ID_0  ISO    NAME_0  ID_1 NAME_1  ID_2     NAME_2    HASC_2  CCN_2 CCA_2  \
# 0   182  PRT  Portugal     1  Évora     1      Évora  PT.EV.EV      0  0705
# 1   182  PRT  Portugal     1  Évora     2  Alandroal  PT.EV.AL      0  0701
# 2   182  PRT  Portugal     1  Évora     3  Arraiolos  PT.EV.AR      0  0702
# 3   182  PRT  Portugal     1  Évora     4      Borba  PT.EV.BO      0  0703
# 4   182  PRT  Portugal     1  Évora     5   Estremoz  PT.EV.ES      0  0704
#
#      TYPE_2     ENGTYPE_2 NL_NAME_2 VARNAME_2  \
# 0  Concelho  Municipality
# 1  Concelho  Municipality
# 2  Concelho  Municipality
# 3  Concelho  Municipality
# 4  Concelho  Municipality
#
#                                               coords
# 0  [(-7.79291391372675, 38.7650718688966), (-7.79...
# 1  [(-7.259370803833008, 38.77350616455101), (-7....
# 2  [(-7.886110782623234, 38.92494583129894), (-7....
# 3  [(-7.463624954223576, 38.923435211181584), (-7...
# 4  [(-7.527699947357121, 39.00079727172857), (-7....

# %%
def plot_shape(id, s=None):
    """ PLOTS A SINGLE SHAPE """
    plt.figure()
    ax = plt.axes()
    ax.set_aspect('equal')
    shape_ex = sf.shape(id)
    x_lon = np.zeros((len(shape_ex.points),1))
    y_lat = np.zeros((len(shape_ex.points),1))
    for ip in range(len(shape_ex.points)):
        x_lon[ip] = shape_ex.points[ip][0]
        y_lat[ip] = shape_ex.points[ip][1]
    plt.plot(x_lon,y_lat) 
    x0 = np.mean(x_lon)
    y0 = np.mean(y_lat)
    plt.text(x0, y0, s, fontsize=10)
    # use bbox (bounding box) to set plot limits
    plt.xlim(shape_ex.bbox[0],shape_ex.bbox[2])
    return x0, y0

# %%
comuna = 'Torres Vedras'
com_id = df_geo[df_geo.NAME_2 == comuna].index.get_values()[0]
plot_shape(com_id, comuna)
# Out:
# (-9.275338437971921, 39.08942914324446)

# %%
def plot_map(sf, x_lim = None, y_lim = None, figsize = (11,9)):
    '''
    Plot map with lim coordinates
    '''
    plt.figure(figsize = figsize)
    id=0
    for shape in sf.shapeRecords():
        x = [i[0] for i in shape.shape.points[:]]
        y = [i[1] for i in shape.shape.points[:]]
        plt.plot(x, y, 'k')
        
        if (x_lim == None) & (y_lim == None):
            x0 = np.mean(x)
            y0 = np.mean(y)
            plt.text(x0, y0, id, fontsize=10)
        id = id+1
    
    if (x_lim != None) & (y_lim != None):     
        plt.xlim(x_lim)
        plt.ylim(y_lim)

# %%
plot_map(sf)
